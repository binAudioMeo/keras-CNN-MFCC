# %%
import librosa
import numpy as np

def extract_features(file_name):
   
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccsscaled = np.mean(mfccs.T,axis=0)
        
    except Exception as e:
        print("Error encountered while parsing file: ", file)
        return None 
     
    return mfccsscaled

# %%
# Load various imports 
import pandas as pd
import os
import librosa

# Set the path to the full UrbanSound dataset 
datasetpath = 'UrbanSound8K/audio/'

metadata = pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')

features = []

# Iterate through each sound file and extract the features 
for index, row in metadata.iterrows():
    file_name = os.path.join(os.path.relpath(datasetpath), 'fold' + str(row["fold"]), str(row["slice_file_name"]))
        
    class_label = row["class"]
    data = extract_features(file_name)
    
    features.append([data, class_label])

# Convert into a Panda dataframe 
featuresdf = pd.DataFrame(features, columns=['feature','class_label'])

print('Finished feature extraction from', len(featuresdf), 'files')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1103
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1523
#   warnings.warn(
# Finished feature extraction from 8732 files

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils.np_utils import to_categorical

# Convert features and corresponding classification labels into numpy arrays
X = np.array(featuresdf.feature.tolist())
y = np.array(featuresdf.class_label.tolist())

# Encode the classification labels
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y))

# %%
# split the dataset 
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.2, random_state = 42)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics 

num_labels = yy.shape[1]
filter_size = 2

# Construct model 
model = Sequential()

model.add(Dense(256, input_shape=(40,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=0)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               10496
# _________________________________________________________________
# activation (Activation)      (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# _________________________________________________________________
# activation_2 (Activation)    (None, 10)                0
# =================================================================
# Total params: 78,858
# Trainable params: 78,858
# Non-trainable params: 0
# _________________________________________________________________
# Pre-training accuracy: 6.8117%

# %%
from keras.callbacks import ModelCheckpoint 
from datetime import datetime 

num_epochs = 100
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.basic_mlp.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()

model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(x_test, y_test), callbacks=[checkpointer], verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/100
# 219/219 [==============================] - 4s 5ms/step - loss: 8.9104 - accuracy: 0.1858 - val_loss: 2.1856 - val_accuracy: 0.2061
#
# Epoch 00001: val_loss improved from inf to 2.18556, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 2/100
# 219/219 [==============================] - 1s 4ms/step - loss: 2.2750 - accuracy: 0.2335 - val_loss: 2.0311 - val_accuracy: 0.2416
#
# Epoch 00002: val_loss improved from 2.18556 to 2.03110, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 3/100
# 219/219 [==============================] - 1s 4ms/step - loss: 2.0649 - accuracy: 0.2710 - val_loss: 1.9024 - val_accuracy: 0.3097
#
# Epoch 00003: val_loss improved from 2.03110 to 1.90238, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 4/100
# 219/219 [==============================] - 1s 4ms/step - loss: 1.9216 - accuracy: 0.3145 - val_loss: 1.7071 - val_accuracy: 0.4121
#
# Epoch 00004: val_loss improved from 1.90238 to 1.70706, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 5/100
# 219/219 [==============================] - 1s 4ms/step - loss: 1.8237 - accuracy: 0.3495 - val_loss: 1.5820 - val_accuracy: 0.4385
#
# Epoch 00005: val_loss improved from 1.70706 to 1.58203, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 6/100
# 219/219 [==============================] - 1s 6ms/step - loss: 1.7231 - accuracy: 0.3832 - val_loss: 1.4928 - val_accuracy: 0.4877
#
# Epoch 00006: val_loss improved from 1.58203 to 1.49279, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 7/100
# 219/219 [==============================] - 2s 8ms/step - loss: 1.6282 - accuracy: 0.4238 - val_loss: 1.3971 - val_accuracy: 0.5432
#
# Epoch 00007: val_loss improved from 1.49279 to 1.39706, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 8/100
# 219/219 [==============================] - 2s 8ms/step - loss: 1.5393 - accuracy: 0.4681 - val_loss: 1.2844 - val_accuracy: 0.5942
#
# Epoch 00008: val_loss improved from 1.39706 to 1.28440, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 9/100
# 219/219 [==============================] - 2s 8ms/step - loss: 1.4307 - accuracy: 0.5047 - val_loss: 1.1666 - val_accuracy: 0.6394
#
# Epoch 00009: val_loss improved from 1.28440 to 1.16663, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 10/100
# 219/219 [==============================] - 2s 8ms/step - loss: 1.3592 - accuracy: 0.5323 - val_loss: 1.1064 - val_accuracy: 0.6663
#
# Epoch 00010: val_loss improved from 1.16663 to 1.10643, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 11/100
# 219/219 [==============================] - 2s 8ms/step - loss: 1.2963 - accuracy: 0.5476 - val_loss: 1.0437 - val_accuracy: 0.6806
#
# Epoch 00011: val_loss improved from 1.10643 to 1.04366, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 12/100
# 219/219 [==============================] - 2s 8ms/step - loss: 1.2385 - accuracy: 0.5788 - val_loss: 0.9841 - val_accuracy: 0.7006
#
# Epoch 00012: val_loss improved from 1.04366 to 0.98412, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 13/100
# 219/219 [==============================] - 2s 8ms/step - loss: 1.1900 - accuracy: 0.5936 - val_loss: 0.9540 - val_accuracy: 0.7109
#
# Epoch 00013: val_loss improved from 0.98412 to 0.95400, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 14/100
# 219/219 [==============================] - 2s 8ms/step - loss: 1.1567 - accuracy: 0.6053 - val_loss: 0.9226 - val_accuracy: 0.7035
#
# Epoch 00014: val_loss improved from 0.95400 to 0.92260, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 15/100
# 219/219 [==============================] - 2s 8ms/step - loss: 1.1027 - accuracy: 0.6243 - val_loss: 0.8752 - val_accuracy: 0.7275
#
# Epoch 00015: val_loss improved from 0.92260 to 0.87523, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 16/100
# 219/219 [==============================] - 2s 8ms/step - loss: 1.0640 - accuracy: 0.6339 - val_loss: 0.8541 - val_accuracy: 0.7464
#
# Epoch 00016: val_loss improved from 0.87523 to 0.85408, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 17/100
# 219/219 [==============================] - 2s 8ms/step - loss: 1.0411 - accuracy: 0.6481 - val_loss: 0.8223 - val_accuracy: 0.7430
#
# Epoch 00017: val_loss improved from 0.85408 to 0.82229, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 18/100
# 219/219 [==============================] - 2s 8ms/step - loss: 1.0105 - accuracy: 0.6490 - val_loss: 0.7849 - val_accuracy: 0.7470
#
# Epoch 00018: val_loss improved from 0.82229 to 0.78488, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 19/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.9936 - accuracy: 0.6654 - val_loss: 0.7603 - val_accuracy: 0.7676
#
# Epoch 00019: val_loss improved from 0.78488 to 0.76033, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 20/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.9351 - accuracy: 0.6826 - val_loss: 0.7399 - val_accuracy: 0.7745
#
# Epoch 00020: val_loss improved from 0.76033 to 0.73992, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 21/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.9406 - accuracy: 0.6763 - val_loss: 0.7167 - val_accuracy: 0.7790
#
# Epoch 00021: val_loss improved from 0.73992 to 0.71672, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 22/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.9006 - accuracy: 0.6916 - val_loss: 0.7122 - val_accuracy: 0.7911
#
# Epoch 00022: val_loss improved from 0.71672 to 0.71217, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 23/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.8973 - accuracy: 0.6962 - val_loss: 0.6946 - val_accuracy: 0.7894
#
# Epoch 00023: val_loss improved from 0.71217 to 0.69465, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 24/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.8631 - accuracy: 0.7008 - val_loss: 0.6715 - val_accuracy: 0.8174
#
# Epoch 00024: val_loss improved from 0.69465 to 0.67152, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 25/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.8455 - accuracy: 0.7148 - val_loss: 0.6683 - val_accuracy: 0.8065
#
# Epoch 00025: val_loss improved from 0.67152 to 0.66834, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 26/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.8402 - accuracy: 0.7181 - val_loss: 0.6361 - val_accuracy: 0.8128
#
# Epoch 00026: val_loss improved from 0.66834 to 0.63615, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 27/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.8332 - accuracy: 0.7191 - val_loss: 0.6181 - val_accuracy: 0.8237
#
# Epoch 00027: val_loss improved from 0.63615 to 0.61813, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 28/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.8248 - accuracy: 0.7213 - val_loss: 0.6445 - val_accuracy: 0.8060
#
# Epoch 00028: val_loss did not improve from 0.61813
# Epoch 29/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.7970 - accuracy: 0.7301 - val_loss: 0.6114 - val_accuracy: 0.8180
#
# Epoch 00029: val_loss improved from 0.61813 to 0.61142, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 30/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.7899 - accuracy: 0.7350 - val_loss: 0.6032 - val_accuracy: 0.8185
#
# Epoch 00030: val_loss improved from 0.61142 to 0.60318, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 31/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.7673 - accuracy: 0.7356 - val_loss: 0.5733 - val_accuracy: 0.8271
#
# Epoch 00031: val_loss improved from 0.60318 to 0.57333, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 32/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.7570 - accuracy: 0.7449 - val_loss: 0.5860 - val_accuracy: 0.8271
#
# Epoch 00032: val_loss did not improve from 0.57333
# Epoch 33/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.7540 - accuracy: 0.7392 - val_loss: 0.5611 - val_accuracy: 0.8283
#
# Epoch 00033: val_loss improved from 0.57333 to 0.56107, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 34/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.7146 - accuracy: 0.7543 - val_loss: 0.5600 - val_accuracy: 0.8283
#
# Epoch 00034: val_loss improved from 0.56107 to 0.56005, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 35/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.7356 - accuracy: 0.7467 - val_loss: 0.5480 - val_accuracy: 0.8283
#
# Epoch 00035: val_loss improved from 0.56005 to 0.54798, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 36/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.7197 - accuracy: 0.7530 - val_loss: 0.5671 - val_accuracy: 0.8288
#
# Epoch 00036: val_loss did not improve from 0.54798
# Epoch 37/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.7081 - accuracy: 0.7588 - val_loss: 0.5387 - val_accuracy: 0.8374
#
# Epoch 00037: val_loss improved from 0.54798 to 0.53875, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 38/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.7213 - accuracy: 0.7528 - val_loss: 0.5443 - val_accuracy: 0.8386
#
# Epoch 00038: val_loss did not improve from 0.53875
# Epoch 39/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6937 - accuracy: 0.7675 - val_loss: 0.5406 - val_accuracy: 0.8357
#
# Epoch 00039: val_loss did not improve from 0.53875
# Epoch 40/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6979 - accuracy: 0.7686 - val_loss: 0.5482 - val_accuracy: 0.8334
#
# Epoch 00040: val_loss did not improve from 0.53875
# Epoch 41/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6699 - accuracy: 0.7685 - val_loss: 0.5213 - val_accuracy: 0.8323
#
# Epoch 00041: val_loss improved from 0.53875 to 0.52131, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 42/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.7049 - accuracy: 0.7611 - val_loss: 0.5329 - val_accuracy: 0.8369
#
# Epoch 00042: val_loss did not improve from 0.52131
# Epoch 43/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6573 - accuracy: 0.7754 - val_loss: 0.5007 - val_accuracy: 0.8512
#
# Epoch 00043: val_loss improved from 0.52131 to 0.50068, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 44/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6532 - accuracy: 0.7761 - val_loss: 0.5227 - val_accuracy: 0.8351
#
# Epoch 00044: val_loss did not improve from 0.50068
# Epoch 45/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6755 - accuracy: 0.7702 - val_loss: 0.5224 - val_accuracy: 0.8403
#
# Epoch 00045: val_loss did not improve from 0.50068
# Epoch 46/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6578 - accuracy: 0.7830 - val_loss: 0.4876 - val_accuracy: 0.8437
#
# Epoch 00046: val_loss improved from 0.50068 to 0.48755, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 47/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6521 - accuracy: 0.7804 - val_loss: 0.5075 - val_accuracy: 0.8517
#
# Epoch 00047: val_loss did not improve from 0.48755
# Epoch 48/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6338 - accuracy: 0.7820 - val_loss: 0.4850 - val_accuracy: 0.8426
#
# Epoch 00048: val_loss improved from 0.48755 to 0.48498, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 49/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6520 - accuracy: 0.7792 - val_loss: 0.4891 - val_accuracy: 0.8443
#
# Epoch 00049: val_loss did not improve from 0.48498
# Epoch 50/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6509 - accuracy: 0.7774 - val_loss: 0.4951 - val_accuracy: 0.8500
#
# Epoch 00050: val_loss did not improve from 0.48498
# Epoch 51/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6272 - accuracy: 0.7855 - val_loss: 0.4644 - val_accuracy: 0.8569
#
# Epoch 00051: val_loss improved from 0.48498 to 0.46442, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 52/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6577 - accuracy: 0.7790 - val_loss: 0.4825 - val_accuracy: 0.8460
#
# Epoch 00052: val_loss did not improve from 0.46442
# Epoch 53/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6205 - accuracy: 0.7920 - val_loss: 0.4706 - val_accuracy: 0.8495
#
# Epoch 00053: val_loss did not improve from 0.46442
# Epoch 54/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6081 - accuracy: 0.7923 - val_loss: 0.4677 - val_accuracy: 0.8615
#
# Epoch 00054: val_loss did not improve from 0.46442
# Epoch 55/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6200 - accuracy: 0.7940 - val_loss: 0.4562 - val_accuracy: 0.8575
#
# Epoch 00055: val_loss improved from 0.46442 to 0.45623, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 56/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.6193 - accuracy: 0.7930 - val_loss: 0.4668 - val_accuracy: 0.8546
#
# Epoch 00056: val_loss did not improve from 0.45623
# Epoch 57/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6042 - accuracy: 0.7970 - val_loss: 0.4710 - val_accuracy: 0.8472
#
# Epoch 00057: val_loss did not improve from 0.45623
# Epoch 58/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5948 - accuracy: 0.7991 - val_loss: 0.4681 - val_accuracy: 0.8540
#
# Epoch 00058: val_loss did not improve from 0.45623
# Epoch 59/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6273 - accuracy: 0.7911 - val_loss: 0.4447 - val_accuracy: 0.8563
#
# Epoch 00059: val_loss improved from 0.45623 to 0.44465, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 60/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.5810 - accuracy: 0.8080 - val_loss: 0.4642 - val_accuracy: 0.8546
#
# Epoch 00060: val_loss did not improve from 0.44465
# Epoch 61/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.6164 - accuracy: 0.7906 - val_loss: 0.4977 - val_accuracy: 0.8529
#
# Epoch 00061: val_loss did not improve from 0.44465
# Epoch 62/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6027 - accuracy: 0.7956 - val_loss: 0.4784 - val_accuracy: 0.8580
#
# Epoch 00062: val_loss did not improve from 0.44465
# Epoch 63/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5825 - accuracy: 0.8024 - val_loss: 0.4815 - val_accuracy: 0.8580
#
# Epoch 00063: val_loss did not improve from 0.44465
# Epoch 64/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5875 - accuracy: 0.8010 - val_loss: 0.4716 - val_accuracy: 0.8563
#
# Epoch 00064: val_loss did not improve from 0.44465
# Epoch 65/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5733 - accuracy: 0.8066 - val_loss: 0.4576 - val_accuracy: 0.8603
#
# Epoch 00065: val_loss did not improve from 0.44465
# Epoch 66/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5915 - accuracy: 0.8053 - val_loss: 0.4634 - val_accuracy: 0.8523
#
# Epoch 00066: val_loss did not improve from 0.44465
# Epoch 67/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5540 - accuracy: 0.8109 - val_loss: 0.4639 - val_accuracy: 0.8603
#
# Epoch 00067: val_loss did not improve from 0.44465
# Epoch 68/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5595 - accuracy: 0.8119 - val_loss: 0.4814 - val_accuracy: 0.8563
#
# Epoch 00068: val_loss did not improve from 0.44465
# Epoch 69/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5822 - accuracy: 0.8013 - val_loss: 0.4672 - val_accuracy: 0.8535
#
# Epoch 00069: val_loss did not improve from 0.44465
# Epoch 70/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5764 - accuracy: 0.8077 - val_loss: 0.4614 - val_accuracy: 0.8466
#
# Epoch 00070: val_loss did not improve from 0.44465
# Epoch 71/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5558 - accuracy: 0.8122 - val_loss: 0.4475 - val_accuracy: 0.8580
#
# Epoch 00071: val_loss did not improve from 0.44465
# Epoch 72/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5760 - accuracy: 0.8063 - val_loss: 0.4761 - val_accuracy: 0.8592
#
# Epoch 00072: val_loss did not improve from 0.44465
# Epoch 73/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.5682 - accuracy: 0.8102 - val_loss: 0.4512 - val_accuracy: 0.8643
#
# Epoch 00073: val_loss did not improve from 0.44465
# Epoch 74/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5578 - accuracy: 0.8135 - val_loss: 0.4494 - val_accuracy: 0.8666
#
# Epoch 00074: val_loss did not improve from 0.44465
# Epoch 75/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.5604 - accuracy: 0.8140 - val_loss: 0.4645 - val_accuracy: 0.8615
#
# Epoch 00075: val_loss did not improve from 0.44465
# Epoch 76/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.5744 - accuracy: 0.8096 - val_loss: 0.4555 - val_accuracy: 0.8689
#
# Epoch 00076: val_loss did not improve from 0.44465
# Epoch 77/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5492 - accuracy: 0.8083 - val_loss: 0.4527 - val_accuracy: 0.8661
#
# Epoch 00077: val_loss did not improve from 0.44465
# Epoch 78/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5391 - accuracy: 0.8175 - val_loss: 0.4732 - val_accuracy: 0.8672
#
# Epoch 00078: val_loss did not improve from 0.44465
# Epoch 79/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5659 - accuracy: 0.8137 - val_loss: 0.4598 - val_accuracy: 0.8706
#
# Epoch 00079: val_loss did not improve from 0.44465
# Epoch 80/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5469 - accuracy: 0.8163 - val_loss: 0.4327 - val_accuracy: 0.8620
#
# Epoch 00080: val_loss improved from 0.44465 to 0.43275, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 81/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5659 - accuracy: 0.8080 - val_loss: 0.4498 - val_accuracy: 0.8615
#
# Epoch 00081: val_loss did not improve from 0.43275
# Epoch 82/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5439 - accuracy: 0.8155 - val_loss: 0.4323 - val_accuracy: 0.8666
#
# Epoch 00082: val_loss improved from 0.43275 to 0.43225, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 83/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5283 - accuracy: 0.8246 - val_loss: 0.4393 - val_accuracy: 0.8701
#
# Epoch 00083: val_loss did not improve from 0.43225
# Epoch 84/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.5563 - accuracy: 0.8090 - val_loss: 0.4629 - val_accuracy: 0.8706
#
# Epoch 00084: val_loss did not improve from 0.43225
# Epoch 85/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5462 - accuracy: 0.8183 - val_loss: 0.4516 - val_accuracy: 0.8689
#
# Epoch 00085: val_loss did not improve from 0.43225
# Epoch 86/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5308 - accuracy: 0.8208 - val_loss: 0.4455 - val_accuracy: 0.8666
#
# Epoch 00086: val_loss did not improve from 0.43225
# Epoch 87/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5409 - accuracy: 0.8188 - val_loss: 0.4401 - val_accuracy: 0.8804
#
# Epoch 00087: val_loss did not improve from 0.43225
# Epoch 88/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5525 - accuracy: 0.8117 - val_loss: 0.4556 - val_accuracy: 0.8649
#
# Epoch 00088: val_loss did not improve from 0.43225
# Epoch 89/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5476 - accuracy: 0.8165 - val_loss: 0.4400 - val_accuracy: 0.8758
#
# Epoch 00089: val_loss did not improve from 0.43225
# Epoch 90/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5405 - accuracy: 0.8222 - val_loss: 0.4356 - val_accuracy: 0.8775
#
# Epoch 00090: val_loss did not improve from 0.43225
# Epoch 91/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.5208 - accuracy: 0.8218 - val_loss: 0.4330 - val_accuracy: 0.8775
#
# Epoch 00091: val_loss did not improve from 0.43225
# Epoch 92/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.5145 - accuracy: 0.8288 - val_loss: 0.4322 - val_accuracy: 0.8752
#
# Epoch 00092: val_loss improved from 0.43225 to 0.43219, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 93/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.5185 - accuracy: 0.8278 - val_loss: 0.4189 - val_accuracy: 0.8724
#
# Epoch 00093: val_loss improved from 0.43219 to 0.41893, saving model to saved_models\weights.best.basic_mlp.hdf5
# Epoch 94/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.5147 - accuracy: 0.8314 - val_loss: 0.4247 - val_accuracy: 0.8666
#
# Epoch 00094: val_loss did not improve from 0.41893
# Epoch 95/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.5206 - accuracy: 0.8266 - val_loss: 0.4375 - val_accuracy: 0.8729
#
# Epoch 00095: val_loss did not improve from 0.41893
# Epoch 96/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.5181 - accuracy: 0.8302 - val_loss: 0.4329 - val_accuracy: 0.8741
#
# Epoch 00096: val_loss did not improve from 0.41893
# Epoch 97/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.5339 - accuracy: 0.8286 - val_loss: 0.4559 - val_accuracy: 0.8678
#
# Epoch 00097: val_loss did not improve from 0.41893
# Epoch 98/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.5059 - accuracy: 0.8285 - val_loss: 0.4339 - val_accuracy: 0.8769
#
# Epoch 00098: val_loss did not improve from 0.41893
# Epoch 99/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.5513 - accuracy: 0.8165 - val_loss: 0.4510 - val_accuracy: 0.8752
#
# Epoch 00099: val_loss did not improve from 0.41893
# Epoch 100/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.5163 - accuracy: 0.8261 - val_loss: 0.4359 - val_accuracy: 0.8741
#
# Epoch 00100: val_loss did not improve from 0.41893
# Training completed in time:  0:02:58.498711

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.9328561425209045
# Testing Accuracy:  0.8740698099136353

# %%
def print_prediction(file_name):
    prediction_feature = np.array([extract_features(file_name)])

    predicted_vector = model.predict_classes(prediction_feature)
    predicted_class = le.inverse_transform(predicted_vector) 
    print("The predicted class is:", predicted_class[0], '\n') 

    predicted_proba_vector = model.predict_proba(prediction_feature) 
    predicted_proba = predicted_proba_vector[0]
    for i in range(len(predicted_proba)): 
        category = le.inverse_transform(np.array([i]))
        print(category[0], "\t\t : ", format(predicted_proba[i], '.32f') )

# %%
filename = 'Evaluation audio/siren_1.wav'

print_prediction(filename)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# The predicted class is: siren
#
# air_conditioner 		 :  0.00000226412885240279138088226318
# car_horn 		 :  0.00024764781119301915168762207031
# children_playing 		 :  0.00059285259339958429336547851562
# dog_bark 		 :  0.05433553457260131835937500000000
# drilling 		 :  0.00010718799603637307882308959961
# engine_idling 		 :  0.22807702422142028808593750000000
# gun_shot 		 :  0.00064293330069631338119506835938
# jackhammer 		 :  0.00010047126852441579103469848633
# siren 		 :  0.70871073007583618164062500000000
# street_music 		 :  0.00718332361429929733276367187500
# C:\Users\user\anaconda3\lib\site-packages\keras\engine\sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
